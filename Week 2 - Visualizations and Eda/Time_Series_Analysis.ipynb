# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('BrentOilPrices.csv')

# %%
data.head()
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45
# 2  22-May-87  18.55
# 3  25-May-87  18.60
# 4  26-May-87  18.63

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9011 entries, 0 to 9010
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9011 non-null   object
#  1   Price   9011 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 140.9+ KB

# %%
data.shape
# Out:
# (9011, 2)

# %%
data.isnull().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %%
from datetime import datetime
import calendar
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9011 entries, 0 to 9010
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9011 non-null   datetime64[ns]
#  1   Price   9011 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 140.9 KB

# %%
data.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
import seaborn as sns

# %%
sns.lineplot(x = "Date", y = "Price",
             data = data)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
data1=data.set_index("Date",drop=True)

# %%
data
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63
# ...           ...
# 2022-11-08  96.85
# 2022-11-09  93.05
# 2022-11-10  94.25
# 2022-11-11  96.37
# 2022-11-14  93.59
#
# [9011 rows x 1 columns]

# %%
data1.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Time Resampling

# %%
#"RULE A Which Means Year and Frequency"
data1.resample(rule='A').min()
# Out:
#             Price
# Date
# 1987-12-31  15.03
# 1988-12-31  11.20
# 1989-12-31  16.05
# 1990-12-31  14.68
# 1991-12-31  17.60
# 1992-12-31  17.05
# 1993-12-31  13.13
# 1994-12-31  13.00
# 1995-12-31  15.35
# 1996-12-31  16.23
# 1997-12-31  15.86
# 1998-12-31   9.10
# 1999-12-31   9.77
# 2000-12-31  21.05
# 2001-12-31  16.51
# 2002-12-31  18.17
# 2003-12-31  23.23
# 2004-12-31  29.02
# 2005-12-31  40.75
# 2006-12-31  55.82
# 2007-12-31  49.95
# 2008-12-31  33.73
# 2009-12-31  39.41
# 2010-12-31  67.18
# 2011-12-31  93.52
# 2012-12-31  88.69
# 2013-12-31  96.84
# 2014-12-31  55.27
# 2015-12-31  35.26
# 2016-12-31  26.01
# 2017-12-31  43.98
# 2018-12-31  50.57
# 2019-12-31  53.23
# 2020-12-31   9.12
# 2021-12-31  50.37
# 2022-12-31  78.25

# %%
data1.resample(rule='A').min().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data1.resample(rule='A').max()
# Out:
#              Price
# Date
# 1987-12-31   20.95
# 1988-12-31   17.95
# 1989-12-31   22.25
# 1990-12-31   41.45
# 1991-12-31   30.28
# 1992-12-31   21.55
# 1993-12-31   19.60
# 1994-12-31   19.03
# 1995-12-31   19.38
# 1996-12-31   25.40
# 1997-12-31   24.83
# 1998-12-31   16.28
# 1999-12-31   26.46
# 2000-12-31   37.43
# 2001-12-31   30.68
# 2002-12-31   32.02
# 2003-12-31   34.94
# 2004-12-31   52.28
# 2005-12-31   67.26
# 2006-12-31   78.26
# 2007-12-31   95.92
# 2008-12-31  143.95
# 2009-12-31   78.68
# 2010-12-31   93.63
# 2011-12-31  126.64
# 2012-12-31  128.14
# 2013-12-31  118.90
# 2014-12-31  115.19
# 2015-12-31   66.33
# 2016-12-31   54.97
# 2017-12-31   66.80
# 2018-12-31   86.07
# 2019-12-31   74.94
# 2020-12-31   70.25
# 2021-12-31   85.76
# 2022-12-31  133.18

# %%
data1.resample(rule='A').max().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='A').min().plot(ax=ax1).set(xlabel='Yearly_Min_Price', ylabel='Price')
data1.resample(rule='A').max().plot(ax=ax2).set(xlabel='Yearly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Max_Price'), Text(0, 0.5, 'Price')]

# %%
data1.resample(rule='A').mean().plot().set(xlabel='Yearly_Mean_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Mean_Price'), Text(0, 0.5, 'Price')]

# %%
#"RULE QS Which Means Quaterly and Frequency"

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='QS').min().plot(ax=ax1).set(xlabel='Quaterly_Min_Price', ylabel='Price')
data1.resample(rule='QS').max().plot(ax=ax2).set(xlabel='Quaterly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Quaterly_Max_Price'), Text(0, 0.5, 'Price')]

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='A').min().plot(kind='bar',ax=ax1).set(xlabel='Yearly_Min_Price', ylabel='Price')
data1.resample(rule='A').max().plot(kind='bar',ax=ax2).set(xlabel='Yearly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Max_Price'), Text(0, 0.5, 'Price')]

# %% [markdown]
# # Rolling

# %%
data1.rolling(15).mean().head(30)
# Out:
#                 Price
# Date
# 1987-05-20        NaN
# 1987-05-21        NaN
# 1987-05-22        NaN
# 1987-05-25        NaN
# 1987-05-26        NaN
# 1987-05-27        NaN
# 1987-05-28        NaN
# 1987-05-29        NaN
# 1987-06-01        NaN
# 1987-06-02        NaN
# 1987-06-03        NaN
# 1987-06-04        NaN
# 1987-06-05        NaN
# 1987-06-08        NaN
# 1987-06-09  18.645333
# 1987-06-10  18.655333
# 1987-06-11  18.670667
# 1987-06-12  18.686000
# 1987-06-16  18.706000
# 1987-06-17  18.732667
# 1987-06-18  18.762667
# 1987-06-19  18.792667
# 1987-06-22  18.827333
# 1987-06-23  18.844000
# 1987-06-24  18.848667
# 1987-06-25  18.845333
# 1987-06-26  18.865333
# 1987-06-29  18.898667
# 1987-06-30  18.920667
# 1987-07-01  18.934000

# %%
data1['price_150 days rolling']=data1['Price'].rolling(150).mean()

# %%
data1[['Price','price_150 days rolling']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#By applying rolling we can get some information about smoothing
