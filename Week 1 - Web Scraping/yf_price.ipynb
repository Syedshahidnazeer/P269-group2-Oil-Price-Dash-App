# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('E:\Excelr-P269-Internship-Project-Group2-OIl-Price-Prediction-And-Forecasting-Using-Python\oil_prices_yahoo1.csv')

# %%
data.head()
# Out:
#          Date      Close
# 0  2000-08-23  32.049999
# 1  2000-08-24  31.629999
# 2  2000-08-25  32.049999
# 3  2000-08-28  32.869999
# 4  2000-08-29  32.720001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5751 entries, 0 to 5750
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5751 non-null   object
#  1   Close   5751 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 90.0+ KB

# %%
data.shape
# Out:
# (5751, 2)

# %%
data.isnull().sum()
# Out:
# Date     0
# Close    0
# dtype: int64

# %%
from datetime import datetime
import calendar
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5751 entries, 0 to 5750
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5751 non-null   datetime64[ns]
#  1   Close   5751 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 90.0 KB

# %%
data.head()
# Out:
#         Date      Close
# 0 2000-08-23  32.049999
# 1 2000-08-24  31.629999
# 2 2000-08-25  32.049999
# 3 2000-08-28  32.869999
# 4 2000-08-29  32.720001

# %%
df=pd.DataFrame(data)

# %%
import seaborn as sns
df.rename(columns = {'Close':'Price'}, inplace = True)

# %%
sns.lineplot(x = "Date", y = "Price",
             data = data)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
data1=data.set_index("Date",drop=True)

# %%
data
# Out:
#            Date      Price
# 0    2000-08-23  32.049999
# 1    2000-08-24  31.629999
# 2    2000-08-25  32.049999
# 3    2000-08-28  32.869999
# 4    2000-08-29  32.720001
# ...         ...        ...
# 5746 2023-07-17  74.150002
# 5747 2023-07-18  75.750000
# 5748 2023-07-19  75.349998
# 5749 2023-07-20  75.629997
# 5750 2023-07-21  77.070000
#
# [5751 rows x 2 columns]

# %%
data1.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Time Resampling

# %%
#"RULE A Which Means Year and Frequency"
data1.resample(rule='A').min()
# Out:
#                 Price
# Date
# 2000-12-31  25.670000
# 2001-12-31  17.450001
# 2002-12-31  18.000000
# 2003-12-31  25.240000
# 2004-12-31  32.480000
# 2005-12-31  42.119999
# 2006-12-31  55.810001
# 2007-12-31  50.480000
# 2008-12-31  33.869999
# 2009-12-31  33.980000
# 2010-12-31  68.010002
# 2011-12-31  75.669998
# 2012-12-31  77.690002
# 2013-12-31  86.680000
# 2014-12-31  53.270000
# 2015-12-31  34.730000
# 2016-12-31  26.209999
# 2017-12-31  42.529999
# 2018-12-31  42.529999
# 2019-12-31  46.540001
# 2020-12-31 -37.630001
# 2021-12-31  47.619999
# 2022-12-31  71.019997
# 2023-12-31  66.739998

# %%
data1.resample(rule='A').min().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data1.resample(rule='A').max()
# Out:
#                  Price
# Date
# 2000-12-31   37.500000
# 2001-12-31   32.099998
# 2002-12-31   32.720001
# 2003-12-31   37.830002
# 2004-12-31   55.169998
# 2005-12-31   69.809998
# 2006-12-31   77.029999
# 2007-12-31   98.180000
# 2008-12-31  145.289993
# 2009-12-31   81.370003
# 2010-12-31   91.510002
# 2011-12-31  113.930000
# 2012-12-31  109.769997
# 2013-12-31  110.529999
# 2014-12-31  107.260002
# 2015-12-31   61.430000
# 2016-12-31   54.060001
# 2017-12-31   60.419998
# 2018-12-31   76.410004
# 2019-12-31   66.300003
# 2020-12-31   63.270000
# 2021-12-31   84.650002
# 2022-12-31  123.699997
# 2023-12-31   83.260002

# %%
data1.resample(rule='A').max().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='A').min().plot(ax=ax1).set(xlabel='Yearly_Min_Price', ylabel='Price')
data1.resample(rule='A').max().plot(ax=ax2).set(xlabel='Yearly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Max_Price'), Text(0, 0.5, 'Price')]

# %%
data1.resample(rule='A').mean().plot().set(xlabel='Yearly_Mean_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Mean_Price'), Text(0, 0.5, 'Price')]

# %%
#"RULE QS Which Means Quaterly and Frequency"

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='QS').min().plot(ax=ax1).set(xlabel='Quaterly_Min_Price', ylabel='Price')
data1.resample(rule='QS').max().plot(ax=ax2).set(xlabel='Quaterly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Quaterly_Max_Price'), Text(0, 0.5, 'Price')]

# %%
fig = plt.figure()
sns.set(rc={'figure.figsize':(15,3)})
ax1 = fig.add_subplot(1,2,1) 
ax2 = fig.add_subplot(1,2,2)
data1.resample(rule='A').min().plot(kind='bar',ax=ax1).set(xlabel='Yearly_Min_Price', ylabel='Price')
data1.resample(rule='A').max().plot(kind='bar',ax=ax2).set(xlabel='Yearly_Max_Price', ylabel='Price')
# Out:
# [Text(0.5, 0, 'Yearly_Max_Price'), Text(0, 0.5, 'Price')]

# %% [markdown]
# # Rolling

# %%
data1.rolling(15).mean().head(30)
# Out:
#                 Price
# Date
# 2000-08-23        NaN
# 2000-08-24        NaN
# 2000-08-25        NaN
# 2000-08-28        NaN
# 2000-08-29        NaN
# 2000-08-30        NaN
# 2000-08-31        NaN
# 2000-09-01        NaN
# 2000-09-05        NaN
# 2000-09-06        NaN
# 2000-09-07        NaN
# 2000-09-08        NaN
# 2000-09-11        NaN
# 2000-09-12        NaN
# 2000-09-13  33.472000
# 2000-09-14  33.608667
# 2000-09-15  33.890000
# 2000-09-18  34.212000
# 2000-09-19  34.454000
# 2000-09-20  34.772667
# 2000-09-21  34.809333
# 2000-09-22  34.779333
# 2000-09-25  34.658667
# 2000-09-26  34.505333
# 2000-09-27  34.275333
# 2000-09-28  33.940000
# 2000-09-29  33.750667
# 2000-10-02  33.554000
# 2000-10-03  33.412000
# 2000-10-04  33.258667

# %%
data1['price_150 days rolling']=data1['Price'].rolling(150).mean()

# %%
data1[['Price','price_150 days rolling']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#By applying rolling we can get some information about smoothing
